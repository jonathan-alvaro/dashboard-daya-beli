# %%
import pandas as pd

# %%
pd.read_excel('Bawang Merah 2016-2017.xlsx')
# Out:
#    Perkembangan Harga Pangan                 Unnamed: 1  \
# 0                        NaN                        NaN
# 1                    Periode                        NaN
# 2                  Komoditas                        NaN
# 3               Tipe Laporan                        NaN
# 4                        NaN                        NaN
# 5                        No.                   Provinsi
# 6                          I             SEMUA PROVINSI
# 7                         II                       ACEH
# 8                        III             SUMATERA UTARA
# 9                         IV             SUMATERA BARAT
# 10                         V                       RIAU
# 11                        VI             KEPULAUAN RIAU
# 12                       VII                      JAMBI
# 13                      VIII                   BENGKULU
# 14                        IX           SUMATERA SELATAN
# 15                         X  KEPULAUAN BANGKA BELITUNG
# ...

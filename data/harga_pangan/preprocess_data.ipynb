# %%
import json
import os

import pandas as pd

# %% [markdown]
# ## Per Food Loading

# %%
dfs_to_merge = []

# %%
bawang_merah = pd.read_excel(
    os.path.join('input', '2016', 'Bawang Merah 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
bawang_merah = bawang_merah.drop(['No.'], axis=1)

bawang_merah = bawang_merah.stack().reset_index()
bawang_merah.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Bawang Merah 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

bawang_merah = bawang_merah.append(df)

bawang_merah = bawang_merah.loc[
    bawang_merah['Harga'] != '-'
].reset_index(drop=True)
bawang_merah['Harga'] = bawang_merah['Harga'].astype(float)

bawang_merah['Bulan'] = pd.DatetimeIndex(
    bawang_merah['Tanggal']
).month
bawang_merah['Tahun'] = pd.DatetimeIndex(
    bawang_merah['Tanggal']
).year
bawang_merah['Tanggal'] = pd.DatetimeIndex(
    bawang_merah['Tanggal']
).day

bawang_merah = bawang_merah.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
bawang_merah = bawang_merah[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
bawang_merah = bawang_merah.rename(columns={'Harga': 'Bawang Merah'})
bawang_merah = bawang_merah.reset_index(drop=True)

bawang_merah['Quarter'] = (bawang_merah['Bulan'] - 1) // 3 + 1
bawang_merah = bawang_merah.drop('Bulan', axis=1)

bawang_merah = bawang_merah.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
bawang_merah = bawang_merah.drop('Tanggal', axis=1)

bawang_merah['Prev Year'] = bawang_merah['Tahun'] - 1
bawang_merah = pd.merge(
    bawang_merah, bawang_merah,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

bawang_merah = bawang_merah.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

bawang_merah.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

bawang_merah['Bawang Merah'] = (bawang_merah['Val'] / bawang_merah['Prev Val'] - 1) * 100
bawang_merah = bawang_merah[['Tahun', 'Quarter', 'Provinsi', 'Bawang Merah']]

dfs_to_merge.append(bawang_merah)

bawang_merah.head()
# Out:
#    Tahun  Quarter       Provinsi  Bawang Merah
# 0   2017        1           ACEH    -11.324534
# 1   2017        1           BALI    -12.749103
# 2   2017        1         BANTEN    -17.344004
# 3   2017        1       BENGKULU    -11.326931
# 4   2017        1  DI YOGYAKARTA    -15.497232

# %%
bawang_putih = pd.read_excel(
    os.path.join('input', '2016', 'Bawang Putih 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
bawang_putih = bawang_putih.drop(['No.'], axis=1)

bawang_putih = bawang_putih.stack().reset_index()
bawang_putih.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Bawang Putih 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

bawang_putih = bawang_putih.append(df)

bawang_putih = bawang_putih.loc[
    bawang_putih['Harga'] != '-'
].reset_index(drop=True)
bawang_putih['Harga'] = bawang_putih['Harga'].astype(float)

bawang_putih['Bulan'] = pd.DatetimeIndex(
    bawang_putih['Tanggal']
).month
bawang_putih['Tahun'] = pd.DatetimeIndex(
    bawang_putih['Tanggal']
).year
bawang_putih['Tanggal'] = pd.DatetimeIndex(
    bawang_putih['Tanggal']
).day

bawang_putih = bawang_putih.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
bawang_putih = bawang_putih[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
bawang_putih = bawang_putih.rename(columns={'Harga': 'Bawang Putih'})
bawang_putih = bawang_putih.reset_index(drop=True)

bawang_putih['Quarter'] = (bawang_putih['Bulan'] - 1) // 3 + 1
bawang_putih = bawang_putih.drop('Bulan', axis=1)

bawang_putih = bawang_putih.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
bawang_putih = bawang_putih.drop('Tanggal', axis=1)

bawang_putih['Prev Year'] = bawang_putih['Tahun'] - 1
bawang_putih = pd.merge(
    bawang_putih, bawang_putih,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

bawang_putih = bawang_putih.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

bawang_putih.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

bawang_putih['Bawang Putih'] = (bawang_putih['Val'] / bawang_putih['Prev Val'] - 1) * 100
bawang_putih = bawang_putih[['Tahun', 'Quarter', 'Provinsi', 'Bawang Putih']]

dfs_to_merge.append(bawang_putih)

bawang_putih.head()
# Out:
#    Tahun  Quarter       Provinsi  Bawang Putih
# 0   2017        1           ACEH     19.778551
# 1   2017        1           BALI      4.422994
# 2   2017        1         BANTEN      4.382751
# 3   2017        1       BENGKULU      1.086678
# 4   2017        1  DI YOGYAKARTA      6.947908

# %%
beras = pd.read_excel(
    os.path.join('input', '2016', 'Beras 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
beras = beras.drop(['No.'], axis=1)

beras = beras.stack().reset_index()
beras.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Beras 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

beras = beras.append(df)

beras = beras.loc[
    beras['Harga'] != '-'
].reset_index(drop=True)
beras['Harga'] = beras['Harga'].astype(float)

beras['Bulan'] = pd.DatetimeIndex(
    beras['Tanggal']
).month
beras['Tahun'] = pd.DatetimeIndex(
    beras['Tanggal']
).year
beras['Tanggal'] = pd.DatetimeIndex(
    beras['Tanggal']
).day

beras = beras.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
beras = beras[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
beras = beras.rename(columns={'Harga': 'Beras'})
beras = beras.reset_index(drop=True)

beras['Quarter'] = (beras['Bulan'] - 1) // 3 + 1
beras = beras.drop('Bulan', axis=1)

beras = beras.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
beras = beras.drop('Tanggal', axis=1)

beras['Prev Year'] = beras['Tahun'] - 1
beras = pd.merge(
    beras, beras,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

beras = beras.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

beras.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

beras['Beras'] = (beras['Val'] / beras['Prev Val'] - 1) * 100
beras = beras[['Tahun', 'Quarter', 'Provinsi', 'Beras']]

dfs_to_merge.append(beras)

beras.head()
# Out:
#    Tahun  Quarter       Provinsi     Beras
# 0   2017        1           ACEH  4.193167
# 1   2017        1           BALI  0.196665
# 2   2017        1         BANTEN  0.318857
# 3   2017        1       BENGKULU  4.247986
# 4   2017        1  DI YOGYAKARTA  0.133218

# %%
cabai_merah = pd.read_excel(
    os.path.join('input', '2016', 'Cabai Merah 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
cabai_merah = cabai_merah.drop(['No.'], axis=1)

cabai_merah = cabai_merah.stack().reset_index()
cabai_merah.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Cabai Merah 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

cabai_merah = cabai_merah.append(df)

cabai_merah = cabai_merah.loc[
    cabai_merah['Harga'] != '-'
].reset_index(drop=True)
cabai_merah['Harga'] = cabai_merah['Harga'].astype(float)

cabai_merah['Bulan'] = pd.DatetimeIndex(
    cabai_merah['Tanggal']
).month
cabai_merah['Tahun'] = pd.DatetimeIndex(
    cabai_merah['Tanggal']
).year
cabai_merah['Tanggal'] = pd.DatetimeIndex(
    cabai_merah['Tanggal']
).day

cabai_merah = cabai_merah.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
cabai_merah = cabai_merah[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
cabai_merah = cabai_merah.rename(columns={'Harga': 'Cabai Merah'})
cabai_merah = cabai_merah.reset_index(drop=True)

cabai_merah['Quarter'] = (cabai_merah['Bulan'] - 1) // 3 + 1
cabai_merah = cabai_merah.drop('Bulan', axis=1)

cabai_merah = cabai_merah.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
cabai_merah = cabai_merah.drop('Tanggal', axis=1)

cabai_merah['Prev Year'] = cabai_merah['Tahun'] - 1
cabai_merah = pd.merge(
    cabai_merah, cabai_merah,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

cabai_merah = cabai_merah.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

cabai_merah.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

cabai_merah['Cabai Merah'] = (cabai_merah['Val'] / cabai_merah['Prev Val'] - 1) * 100
cabai_merah = cabai_merah[['Tahun', 'Quarter', 'Provinsi', 'Cabai Merah']]

dfs_to_merge.append(cabai_merah)

cabai_merah.head()
# Out:
#    Tahun  Quarter       Provinsi  Cabai Merah
# 0   2017        1           ACEH   -45.444284
# 1   2017        1           BALI    -5.235270
# 2   2017        1         BANTEN   -19.535168
# 3   2017        1       BENGKULU   -24.433068
# 4   2017        1  DI YOGYAKARTA   -19.216160

# %%
cabai_rawit = pd.read_excel(
    os.path.join('input', '2016', 'Cabai Rawit 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
cabai_rawit = cabai_rawit.drop(['No.'], axis=1)

cabai_rawit = cabai_rawit.stack().reset_index()
cabai_rawit.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Cabai Rawit 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

cabai_rawit = cabai_rawit.append(df)

cabai_rawit = cabai_rawit.loc[
    cabai_rawit['Harga'] != '-'
].reset_index(drop=True)
cabai_rawit['Harga'] = cabai_rawit['Harga'].astype(float)

cabai_rawit['Bulan'] = pd.DatetimeIndex(
    cabai_rawit['Tanggal']
).month
cabai_rawit['Tahun'] = pd.DatetimeIndex(
    cabai_rawit['Tanggal']
).year
cabai_rawit['Tanggal'] = pd.DatetimeIndex(
    cabai_rawit['Tanggal']
).day

cabai_rawit = cabai_rawit.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
cabai_rawit = cabai_rawit[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
cabai_rawit = cabai_rawit.rename(columns={'Harga': 'Cabai Rawit'})
cabai_rawit = cabai_rawit.reset_index(drop=True)

cabai_rawit['Quarter'] = (cabai_rawit['Bulan'] - 1) // 3 + 1
cabai_rawit = cabai_rawit.drop('Bulan', axis=1)

cabai_rawit = cabai_rawit.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
cabai_rawit = cabai_rawit.drop('Tanggal', axis=1)

cabai_rawit['Prev Year'] = cabai_rawit['Tahun'] - 1
cabai_rawit = pd.merge(
    cabai_rawit, cabai_rawit,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

cabai_rawit = cabai_rawit.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

cabai_rawit.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

cabai_rawit['Cabai Rawit'] = (cabai_rawit['Val'] / cabai_rawit['Prev Val'] - 1) * 100
cabai_rawit = cabai_rawit[['Tahun', 'Quarter', 'Provinsi', 'Cabai Rawit']]

dfs_to_merge.append(cabai_rawit)

cabai_rawit.head()
# Out:
#    Tahun  Quarter       Provinsi  Cabai Rawit
# 0   2017        1           ACEH    -5.259044
# 1   2017        1           BALI   130.590029
# 2   2017        1         BANTEN   105.050762
# 3   2017        1       BENGKULU    26.212299
# 4   2017        1  DI YOGYAKARTA    97.296034

# %%
daging_ayam = pd.read_excel(
    os.path.join('input', '2016', 'Daging Ayam 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
daging_ayam = daging_ayam.drop(['No.'], axis=1)

daging_ayam = daging_ayam.stack().reset_index()
daging_ayam.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Daging Ayam 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

daging_ayam = daging_ayam.append(df)

daging_ayam = daging_ayam.loc[
    daging_ayam['Harga'] != '-'
].reset_index(drop=True)
daging_ayam['Harga'] = daging_ayam['Harga'].astype(float)

daging_ayam['Bulan'] = pd.DatetimeIndex(
    daging_ayam['Tanggal']
).month
daging_ayam['Tahun'] = pd.DatetimeIndex(
    daging_ayam['Tanggal']
).year
daging_ayam['Tanggal'] = pd.DatetimeIndex(
    daging_ayam['Tanggal']
).day

daging_ayam = daging_ayam.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
daging_ayam = daging_ayam[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
daging_ayam = daging_ayam.rename(columns={'Harga': 'Daging Ayam'})
daging_ayam = daging_ayam.reset_index(drop=True)

daging_ayam['Quarter'] = (daging_ayam['Bulan'] - 1) // 3 + 1
daging_ayam = daging_ayam.drop('Bulan', axis=1)

daging_ayam = daging_ayam.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
daging_ayam = daging_ayam.drop('Tanggal', axis=1)

daging_ayam['Prev Year'] = daging_ayam['Tahun'] - 1
daging_ayam = pd.merge(
    daging_ayam, daging_ayam,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

daging_ayam = daging_ayam.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

daging_ayam.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

daging_ayam['Daging Ayam'] = (daging_ayam['Val'] / daging_ayam['Prev Val'] - 1) * 100
daging_ayam = daging_ayam[['Tahun', 'Quarter', 'Provinsi', 'Daging Ayam']]

dfs_to_merge.append(daging_ayam)

daging_ayam.head()
# Out:
#    Tahun  Quarter       Provinsi  Daging Ayam
# 0   2017        1           ACEH    -8.270415
# 1   2017        1           BALI     0.368029
# 2   2017        1         BANTEN     4.883377
# 3   2017        1       BENGKULU    -3.689297
# 4   2017        1  DI YOGYAKARTA    -0.698869

# %%
daging_sapi = pd.read_excel(
    os.path.join('input', '2016', 'Daging Sapi 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
daging_sapi = daging_sapi.drop(['No.'], axis=1)

daging_sapi = daging_sapi.stack().reset_index()
daging_sapi.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Daging Sapi 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

daging_sapi = daging_sapi.append(df)

daging_sapi = daging_sapi.loc[
    daging_sapi['Harga'] != '-'
].reset_index(drop=True)
daging_sapi['Harga'] = daging_sapi['Harga'].astype(float)

daging_sapi['Bulan'] = pd.DatetimeIndex(
    daging_sapi['Tanggal']
).month
daging_sapi['Tahun'] = pd.DatetimeIndex(
    daging_sapi['Tanggal']
).year
daging_sapi['Tanggal'] = pd.DatetimeIndex(
    daging_sapi['Tanggal']
).day

daging_sapi = daging_sapi.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
daging_sapi = daging_sapi[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
daging_sapi = daging_sapi.rename(columns={'Harga': 'Daging Sapi'})
daging_sapi = daging_sapi.reset_index(drop=True)

daging_sapi['Quarter'] = (daging_sapi['Bulan'] - 1) // 3 + 1
daging_sapi = daging_sapi.drop('Bulan', axis=1)

daging_sapi = daging_sapi.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
daging_sapi = daging_sapi.drop('Tanggal', axis=1)

daging_sapi['Prev Year'] = daging_sapi['Tahun'] - 1
daging_sapi = pd.merge(
    daging_sapi, daging_sapi,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

daging_sapi = daging_sapi.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

daging_sapi.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

daging_sapi['Daging Sapi'] = (daging_sapi['Val'] / daging_sapi['Prev Val'] - 1) * 100
daging_sapi = daging_sapi[['Tahun', 'Quarter', 'Provinsi', 'Daging Sapi']]

dfs_to_merge.append(daging_sapi)

daging_sapi.head()
# Out:
#    Tahun  Quarter       Provinsi  Daging Sapi
# 0   2017        1           ACEH     2.081643
# 1   2017        1           BALI     1.507717
# 2   2017        1         BANTEN     2.599407
# 3   2017        1       BENGKULU    -0.576266
# 4   2017        1  DI YOGYAKARTA    -0.086672

# %%
gula_pasir = pd.read_excel(
    os.path.join('input', '2016', 'Gula Pasir 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
gula_pasir = gula_pasir.drop(['No.'], axis=1)

gula_pasir = gula_pasir.stack().reset_index()
gula_pasir.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Gula Pasir 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

gula_pasir = gula_pasir.append(df)

gula_pasir = gula_pasir.loc[
    gula_pasir['Harga'] != '-'
].reset_index(drop=True)
gula_pasir['Harga'] = gula_pasir['Harga'].astype(float)

gula_pasir['Bulan'] = pd.DatetimeIndex(
    gula_pasir['Tanggal']
).month
gula_pasir['Tahun'] = pd.DatetimeIndex(
    gula_pasir['Tanggal']
).year
gula_pasir['Tanggal'] = pd.DatetimeIndex(
    gula_pasir['Tanggal']
).day

gula_pasir = gula_pasir.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
gula_pasir = gula_pasir[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
gula_pasir = gula_pasir.rename(columns={'Harga': 'Gula Pasir'})
gula_pasir = gula_pasir.reset_index(drop=True)

gula_pasir['Quarter'] = (gula_pasir['Bulan'] - 1) // 3 + 1
gula_pasir = gula_pasir.drop('Bulan', axis=1)

gula_pasir = gula_pasir.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
gula_pasir = gula_pasir.drop('Tanggal', axis=1)

gula_pasir['Prev Year'] = gula_pasir['Tahun'] - 1
gula_pasir = pd.merge(
    gula_pasir, gula_pasir,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

gula_pasir = gula_pasir.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

gula_pasir.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

gula_pasir['Gula Pasir'] = (gula_pasir['Val'] / gula_pasir['Prev Val'] - 1) * 100
gula_pasir = gula_pasir[['Tahun', 'Quarter', 'Provinsi', 'Gula Pasir']]

dfs_to_merge.append(gula_pasir)

gula_pasir.head()
# Out:
#    Tahun  Quarter       Provinsi  Gula Pasir
# 0   2017        1           ACEH   -9.996469
# 1   2017        1           BALI   -7.727141
# 2   2017        1         BANTEN   -3.959113
# 3   2017        1       BENGKULU   -4.139504
# 4   2017        1  DI YOGYAKARTA   -6.644600

# %%
minyak_goreng = pd.read_excel(
    os.path.join('input', '2016', 'Minyak Goreng 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
minyak_goreng = minyak_goreng.drop(['No.'], axis=1)

minyak_goreng = minyak_goreng.stack().reset_index()
minyak_goreng.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Minyak Goreng 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

minyak_goreng = minyak_goreng.append(df)

minyak_goreng = minyak_goreng.loc[
    minyak_goreng['Harga'] != '-'
].reset_index(drop=True)
minyak_goreng['Harga'] = minyak_goreng['Harga'].astype(float)

minyak_goreng['Bulan'] = pd.DatetimeIndex(
    minyak_goreng['Tanggal']
).month
minyak_goreng['Tahun'] = pd.DatetimeIndex(
    minyak_goreng['Tanggal']
).year
minyak_goreng['Tanggal'] = pd.DatetimeIndex(
    minyak_goreng['Tanggal']
).day

minyak_goreng = minyak_goreng.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
minyak_goreng = minyak_goreng[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
minyak_goreng = minyak_goreng.rename(columns={'Harga': 'Minyak Goreng'})
minyak_goreng = minyak_goreng.reset_index(drop=True)

minyak_goreng['Quarter'] = (minyak_goreng['Bulan'] - 1) // 3 + 1
minyak_goreng = minyak_goreng.drop('Bulan', axis=1)

minyak_goreng = minyak_goreng.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
minyak_goreng = minyak_goreng.drop('Tanggal', axis=1)

minyak_goreng['Prev Year'] = minyak_goreng['Tahun'] - 1
minyak_goreng = pd.merge(
    minyak_goreng, minyak_goreng,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

minyak_goreng = minyak_goreng.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

minyak_goreng.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

minyak_goreng['Minyak Goreng'] = (minyak_goreng['Val'] / minyak_goreng['Prev Val'] - 1) * 100
minyak_goreng = minyak_goreng[['Tahun', 'Quarter', 'Provinsi', 'Minyak Goreng']]

dfs_to_merge.append(minyak_goreng)

minyak_goreng.head()
# Out:
#    Tahun  Quarter       Provinsi  Minyak Goreng
# 0   2017        1           ACEH       3.713006
# 1   2017        1           BALI       5.411922
# 2   2017        1         BANTEN       4.829372
# 3   2017        1       BENGKULU       0.762599
# 4   2017        1  DI YOGYAKARTA       5.032151

# %%
telur_ayam = pd.read_excel(
    os.path.join('input', '2016', 'Telur Ayam 2016-2017.xlsx'),
    skiprows=6,
    index_col=1
)
telur_ayam = telur_ayam.drop(['No.'], axis=1)

telur_ayam = telur_ayam.stack().reset_index()
telur_ayam.columns = ['Provinsi', 'Tanggal', 'Harga']

df = pd.read_excel(
    os.path.join('input', '2018', 'Telur Ayam 2018-2019.xlsx'),
    skiprows=6,
    index_col=1
)
df = df.drop(['No.'], axis=1)
df = df.stack().reset_index()
df.columns = ['Provinsi', 'Tanggal', 'Harga']

telur_ayam = telur_ayam.append(df)

telur_ayam = telur_ayam.loc[
    telur_ayam['Harga'] != '-'
].reset_index(drop=True)
telur_ayam['Harga'] = telur_ayam['Harga'].astype(float)

telur_ayam['Bulan'] = pd.DatetimeIndex(
    telur_ayam['Tanggal']
).month
telur_ayam['Tahun'] = pd.DatetimeIndex(
    telur_ayam['Tanggal']
).year
telur_ayam['Tanggal'] = pd.DatetimeIndex(
    telur_ayam['Tanggal']
).day

telur_ayam = telur_ayam.sort_values(
    by=['Tahun', 'Bulan', 'Tanggal', 'Provinsi']
)
telur_ayam = telur_ayam[[
    'Tahun', 'Bulan', 'Tanggal', 'Provinsi', 'Harga'
]]
telur_ayam = telur_ayam.rename(columns={'Harga': 'Telur Ayam'})
telur_ayam = telur_ayam.reset_index(drop=True)

telur_ayam['Quarter'] = (telur_ayam['Bulan'] - 1) // 3 + 1
telur_ayam = telur_ayam.drop('Bulan', axis=1)

telur_ayam = telur_ayam.groupby(
    ['Tahun', 'Quarter', 'Provinsi']
).mean().reset_index()
telur_ayam = telur_ayam.drop('Tanggal', axis=1)

telur_ayam['Prev Year'] = telur_ayam['Tahun'] - 1
telur_ayam = pd.merge(
    telur_ayam, telur_ayam,
    left_on=['Prev Year', 'Quarter', 'Provinsi'],
    right_on=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

telur_ayam = telur_ayam.drop([
    'Prev Year_x', 'Tahun_y', 'Prev Year_y'
], axis=1)

telur_ayam.columns = ['Tahun', 'Quarter', 'Provinsi', 'Val', 'Prev Val']

telur_ayam['Telur Ayam'] = (telur_ayam['Val'] / telur_ayam['Prev Val'] - 1) * 100
telur_ayam = telur_ayam[['Tahun', 'Quarter', 'Provinsi', 'Telur Ayam']]

dfs_to_merge.append(telur_ayam)

telur_ayam.head()
# Out:
#    Tahun  Quarter       Provinsi  Telur Ayam
# 0   2017        1           ACEH   -5.368728
# 1   2017        1           BALI    0.700025
# 2   2017        1         BANTEN   -3.108998
# 3   2017        1       BENGKULU   -3.409647
# 4   2017        1  DI YOGYAKARTA   -1.991022

# %%
from functools import reduce

merged_food_prices = reduce(
    pd.merge, dfs_to_merge
)

merged_food_prices['index'] = 0

food_index_weights = pd.read_csv(
    os.path.join('input', 'food_weight.csv')
)

for col in merged_food_prices.columns[:-1]:
    if merged_food_prices[col].dtype != 'float64':
        continue
    
    weight = food_index_weights.loc[
        food_index_weights['food'] == col
    ]['weight'].values
    
    merged_food_prices['index'] = (
        merged_food_prices['index']
        + merged_food_prices[col] * weight
    )

merged_food_prices.head()
# Out:
#    Tahun  Quarter       Provinsi  Bawang Merah  Bawang Putih     Beras  \
# 0   2017        1           ACEH    -11.324534     19.778551  4.193167
# 1   2017        1           BALI    -12.749103      4.422994  0.196665
# 2   2017        1         BANTEN    -17.344004      4.382751  0.318857
# 3   2017        1       BENGKULU    -11.326931      1.086678  4.247986
# 4   2017        1  DI YOGYAKARTA    -15.497232      6.947908  0.133218
#
#    Cabai Merah  Cabai Rawit  Daging Ayam  Daging Sapi  Gula Pasir  \
# 0   -45.444284    -5.259044    -8.270415     2.081643   -9.996469
# 1    -5.235270   130.590029     0.368029     1.507717   -7.727141
# 2   -19.535168   105.050762     4.883377     2.599407   -3.959113
# 3   -24.433068    26.212299    -3.689297    -0.576266   -4.139504
# 4   -19.216160    97.296034    -0.698869    -0.086672   -6.644600
#
#    Minyak Goreng  Telur Ayam      index
# 0       3.713006   -5.368728 -16.918948
# 1       5.411922    0.700025  13.633233
# 2       4.829372   -3.108998   9.323826
# 3       0.762599   -3.409647  -1.358759
# 4       5.032151   -1.991022  -0.144061

# %%
province_mapping = {
    'NUSATENGGARA BARAT': 'NUSA TENGGARA BARAT',
    'DAERAH ISTIMEWA YOGYAKARTA': 'DI YOGYAKARTA',
    'BANGKA BELITUNG': 'KEPULAUAN BANGKA BELITUNG',
    'DI. ACEH': 'ACEH'
}

# %%
with open(os.path.join('input', 'indonesia-prov.json')) as f:
    province_data = json.load(f)['features']

province_ids = {}
for province in province_data:
    properties = province['properties']
    
    if properties['Propinsi'] in province_mapping:
        province_key = province_mapping[properties['Propinsi']]
    else:
        province_key = properties['Propinsi']
        
    province_ids[province_key] = properties['ID']

province_ids['SEMUA PROVINSI'] = -1
province_ids
# Out:
# {'NUSA TENGGARA BARAT': 2,
#  'GORONTALO': 3,
#  'SULAWESI TENGGARA': 4,
#  'DI YOGYAKARTA': 5,
#  'JAWA TENGAH': 6,
#  'BANTEN': 7,
#  'JAWA TIMUR': 8,
#  'MALUKU UTARA': 9,
#  'MALUKU': 10,
#  'KALIMANTAN SELATAN': 11,
#  'KALIMANTAN BARAT': 12,
#  'SULAWESI SELATAN': 13,
#  'DKI JAKARTA': 14,
#  'JAWA BARAT': 15,
#  'PAPUA': 16,
#  'NUSA TENGGARA TIMUR': 17,
#  'BALI': 18,
#  'RIAU': 19,
#  'KEPULAUAN RIAU': 76,
#  'SULAWESI BARAT': 77,
#  'SULAWESI TENGAH': 20,
#  'KALIMANTAN TIMUR': 21,
#  'SULAWESI UTARA': 22,
#  'PAPUA BARAT': 23,
#  'SUMATERA UTARA': 24,
#  'KEPULAUAN BANGKA BELITUNG': 25,
#  'SUMATERA BARAT': 26,
#  'KALIMANTAN TENGAH': 27,
#  'SUMATERA SELATAN': 28,
#  'JAMBI': 29,
#  'LAMPUNG': 30,
#  'BENGKULU': 31,
#  'ACEH': 32,
#  'SEMUA PROVINSI': -1}

# %%
merged_food_prices['Provinsi'] = merged_food_prices['Provinsi'].replace(province_ids)

# %%
merged_food_prices.to_csv(
    os.path.join('output', 'food_data.csv'),
    index=False
)

# %%
merged_food_prices = pd.read_csv(
    os.path.join('output', 'food_data.csv')
)
merged_food_prices.head()
# Out:
#    Tahun  Quarter Provinsi  Bawang Merah  Bawang Putih     Beras  Cabai Merah  \
# 0   2017        1       32    -11.324534     19.778551  4.193167   -45.444284
# 1   2017        1       18    -12.749103      4.422994  0.196665    -5.235270
# 2   2017        1        7    -17.344004      4.382751  0.318857   -19.535168
# 3   2017        1       31    -11.326931      1.086678  4.247986   -24.433068
# 4   2017        1        5    -15.497232      6.947908  0.133218   -19.216160
#
#    Cabai Rawit  Daging Ayam  Daging Sapi  Gula Pasir  Minyak Goreng  \
# 0    -5.259044    -8.270415     2.081643   -9.996469       3.713006
# 1   130.590029     0.368029     1.507717   -7.727141       5.411922
# 2   105.050762     4.883377     2.599407   -3.959113       4.829372
# 3    26.212299    -3.689297    -0.576266   -4.139504       0.762599
# 4    97.296034    -0.698869    -0.086672   -6.644600       5.032151
#
#    Telur Ayam      index
# 0   -5.368728 -16.918948
# 1    0.700025  13.633233
# 2   -3.108998   9.323826
# 3   -3.409647  -1.358759
# 4   -1.991022  -0.144061

# %%
len(merged_food_prices)
# Out:
# 420

# %%
json_data = {}
merged_food_prices['label'] = (
    merged_food_prices['Tahun'].apply(str) + '-Q'
    + merged_food_prices['Quarter'].apply(str)
)

for period in pd.unique(merged_food_prices['label']):
    period_data = merged_food_prices.loc[
        merged_food_prices['label'] == period
    ].reset_index(drop=True)
    
    period_dict = {}
    
    for location in pd.unique(merged_food_prices['Provinsi']):
        location_data = period_data.loc[
            period_data['Provinsi'] == location
        ]
        location_dict = {}
        
        for col in location_data.columns:
            if location_data[col].dtype != 'float64':
                continue
            location_dict[col] = float(location_data[col].values[0])
        
        period_dict[location] = location_dict
    
    json_data[period] = period_dict

with open(os.path.join('output', 'food.json'), 'w') as f:
    json.dump(json_data, f)

# %% [markdown]
# ## Merge both periods' data

# %%
complete_data = pd.read_csv(os.path.join('output', 'food_data.csv'))

complete_data = complete_data.sort_values(
    by=['Tahun', 'Quarter', 'Provinsi']
).reset_index(drop=True)

complete_data.head()
# Out:
#    Tahun  Quarter Provinsi  Bawang Merah  Bawang Putih     Beras  Cabai Merah  \
# 0   2017        1       -1    -15.076768      0.891155 -0.421442    -9.255638
# 1   2017        1       10    -11.266088     -0.451599 -0.939976    20.566750
# 2   2017        1       11    -19.823808      1.730512 -2.445141   -10.488923
# 3   2017        1       12    -18.997859      2.498702 -4.611952   -15.874636
# 4   2017        1       13    -17.613906      3.214424  1.140546   -10.991936
#
#    Cabai Rawit  Daging Ayam  Daging Sapi  Gula Pasir  Minyak Goreng  \
# 0    71.276886    -1.505762    -1.274851   -6.294494       2.734519
# 1    70.699992     1.564605     3.489897   -3.470012       1.272769
# 2    56.227602     0.870635     1.070414   -7.729861       3.861264
# 3    85.039187     0.893610    -2.455136  -10.295695       1.897952
# 4   161.694331     0.738723     1.090107   -8.016702       1.257676
#
#    Telur Ayam      index
# 0   -2.142857  -5.757247
# 1   -7.454550   7.703838
# 2    1.783234 -10.366851
# 3   -6.710542 -26.721805
# 4    2.884582  16.667471

# %%
complete_data.to_csv(
    os.path.join('output', 'complete.csv')
)

# %%
json_data = {}
complete_data['label'] = (
    complete_data['Tahun'].apply(str) + '-Q'
    + complete_data['Quarter'].apply(str)
)

for period in pd.unique(complete_data['label']):
    period_data = complete_data.loc[
        complete_data['label'] == period
    ].reset_index(drop=True)
    
    period_dict = {}
    
    for location in pd.unique(complete_data['Provinsi']):
        location_data = period_data.loc[
            period_data['Provinsi'] == location
        ]
        location_dict = {}
        
        for col in location_data.columns:
            if location_data[col].dtype != 'float64':
                continue
            location_dict[col] = float(location_data[col].values[0])
        
        period_dict[location] = location_dict
    
    json_data[period] = period_dict

with open(os.path.join('output', 'data.json'), 'w') as f:
    json.dump(json_data, f)

# %%
json_data
# Out:
# {'2017-Q1': {'-1': {'Bawang Merah': -15.076767676767664,
#    'Beras': 5.092717616347109,
#    'Cabai Merah': -39.01141575566268,
#    'Cabai Rawit': -20.446781898242765,
#    'Daging Ayam': -4.397512552712824,
#    'Daging Sapi': 0.2234773690897196,
#    'Gula Pasir': -7.161805646654129,
#    'Minyak Goreng': -0.5557562163986063,
#    'Telur Ayam': -2.484228674424982,
#    'index': -17.710229076078626},
#   '32': {'Bawang Merah': -16.91959393085407,
#    'Bawang Putih': 29.61685081088068,
#    'Beras': 2.674843623350198,
#    'Cabai Merah': -32.50649398163392,
#    'Cabai Rawit': -28.73924794894077,
#    'Daging Ayam': -11.665091814728568,
#    'Daging Sapi': 5.626156572851127,
#    'Gula Pasir': -11.767980009710932,
#    'Minyak Goreng': 4.05336735466153,
#    'Telur Ayam': -7.950370832466913,
#    'index': -25.376204674135238},
#   '4': {'Bawang Merah': -25.769984393155408,
#    'Bawang Putih': -11.137806293085797,
#    'Beras': 1.638743404998233,
#    'Cabai Merah': 19.50591299885345,
#    'Cabai Rawit': 58.89033456535675,
#    'Daging Ayam': 16.364757141456174,
#    'Daging Sapi': -5.835497835497838,
#    'Gula Pasir': -5.467545212393099,
#    'Minyak Goreng': 14.457176537227976,
#    'Telur Ayam': 1.8287869077804773,
#    'index': 34.51266487094398},
#   '5': {'Bawang Merah': -25.00269541778976,
#    'Bawang Putih': 8.271414552081868,
#    'Beras': 0.1996543298170339,
#    'Cabai Merah': -30.782426379491078,
#    'Cabai Rawit': 0.982862615874014,
#    'Daging Ayam': -0.747730105038269,
#    'Daging Sapi': -0.5668274294583941,
#    'Gula Pasir': -10.880524541490118,
#    'Minyak Goreng': 3.4194257101982433,
#    'Telur Ayam': 5.6589990287474246,
#    'index': -17.603464133392656},
#   '6': {'Bawang Merah': -29.298875329026075,
#    'Bawang Putih': -1.281275516662428,
#    'Beras': 1.6664799985066423,
#    'Cabai Merah': -27.559642184472512,
#    'Cabai Rawit': 1.3085723950876815,
#    'Daging Ayam': -4.203986758590017,
#    'Daging Sapi': 1.253983768516398,
#    'Gula Pasir': -9.30990578049402,
#    'Minyak Goreng': 1.3478680145346809,
#    'Telur Ayam': 3.849815927378253,
#    'index': -18.28367739675028},
#   '7': {'Bawang Merah': -26.992804042032038,
#    'Bawang Putih': -13.047573180888994,
#    'Beras': 1.3117565866926473,
#    'Cabai Merah': -30.075828724477386,
#    'Cabai Rawit': -0.2719181646251512,
#    'Daging Ayam': 4.119922263723197,
#    'Daging Sapi': 3.6480189687355216,
#    'Gula Pasir': -7.730372500240778,
#    'Minyak Goreng': 3.9704988790412177,
#    'Telur Ayam': 2.481665163427249,
#    'index': -9.286573503655402},
#   '76': {'Bawang Merah': 29.22167588834257,
#    'Bawang Putih': -8.257107211355574,
#    'Beras': 1.4159917454663828,
#    'Cabai Merah': -17.24037648999478,
#    'Cabai Rawit': -4.723237244552703,
#    'Daging Ayam': 0.6247307666235935,
#    'Daging Sapi': 0.7495215627051799,
#    'Gula Pasir': -12.035743950637569,
#    'Minyak Goreng': 1.5706249290163619,
#    'Telur Ayam': -2.101900535729817,
#    'index': -0.2275206124672984},
#   '77': {'Bawang Merah': -34.47945318082086,
#    'Bawang Putih': -11.899697786490238,
#    'Beras': 4.468631146879054,
#    'Cabai Merah': -25.88339385237037,
#    'Cabai Rawit': 9.975775359104723,
#    'Daging Ayam': -6.3415120189313825,
#    'Daging Sapi': -1.2072411914058834,
#    'Gula Pasir': -10.331820573533278,
#    'Minyak Goreng': -1.5195193039955646,
#    'Telur Ayam': 2.5330527813655297,
#    'index': -16.243442574607954},
#   '8': {'Bawang Merah': -30.245472992987665,
#    'Bawang Putih': -17.133244699111778,
#    'Beras': 0.7115489874110592,
#    'Cabai Merah': -33.06292381159855,
#    'Cabai Rawit': 6.856084252036897,
#    'Daging Ayam': -2.047800689560342,
#    'Daging Sapi': -1.585212207826403,
#    'Gula Pasir': -8.462826038248128,
#    'Minyak Goreng': 0.9368375289034558,
#    'Telur Ayam': 5.925656663570144,
#    'index': -23.688574456600485},
#   '9': {'Bawang Merah': -19.278315561055813,
#    'Bawang Putih': -12.504985379823374,
#    'Beras': 1.2496234662525474,
#    'Cabai Merah': -3.006118747097464,
#    'Cabai Rawit': 35.85976303934733,
#    'Daging Ayam': 11.392410681591734,
#    'Daging Sapi': -6.021464004507172,
#    'Gula Pasir': -9.324043715846996,
#    'Minyak Goreng': 3.5969864022894704,
#    'Telur Ayam': -27.321220558570324,
#    'index': -10.484438001250039},
#   'KALIMANTAN UTARA': {'Bawang Merah': -27.58776540369801,
#    'Bawang Putih': -8.9944265441396,
#    'Beras': -0.5651844791948579,
#    'Cabai Merah': -6.453024002021534,
#    'Cabai Rawit': 34.37200271364074,
#    'Daging Ayam': 4.570852798387848,
#    'Daging Sapi': -0.25740674829328736,
#    'Gula Pasir': -10.602976306665557,
#    'Minyak Goreng': 5.086082270994874,
#    'Telur Ayam': 6.112298937534955,
#    'index': -2.8942327566281056}},
#  '2017-Q4': {'-1': {'Bawang Merah': -30.507470924048953,
#    'Bawang Putih': -24.407899643889827,
#    'Beras': 1.2490959719143602,
#    'Cabai Merah': -28.994596739011698,
#    'Cabai Rawit': -14.540868046635234,
#    'Daging Ayam': -0.8821270088354759,
#    'Daging Sapi': -0.017328616948397713,
#    'Gula Pasir': -6.9067250573604735,
#    'Minyak Goreng': 2.1946435980816803,
#    'Telur Ayam': 2.459208984433081,
#    'index': -22.686491198465124},
#   '10': {'Bawang Merah': -31.27994644394835,
#    'Bawang Putih': -16.69278291541172,
#    'Beras': 0.3578950364298672,
#    'Cabai Merah': 3.7946551942685587,
#    'Cabai Rawit': 26.49862626009343,
#    'Daging Ayam': 7.421837419439736,
#    'Daging Sapi': 2.2329212726697407,
#    'Gula Pasir': -3.918620265204509,
#    'Minyak Goreng': 0.8310835258426241,
#    'Telur Ayam': -12.987828053367178,
#    'index': -5.777901112256979},
#   '11': {'Bawang Merah': -36.99201102822737,
#    'Bawang Putih': -29.824378476005343,
#    'Beras': -3.8806396413477273,
#    'Cabai Merah': -16.53068909250659,
#    'Cabai Rawit': -39.37374613963439,
#    'Daging Ayam': -2.718242180259234,
#    'Telur Ayam': -2.988720454055616,
#    'index': 3.0142478817087035},
#   '7': {'Bawang Merah': 10.7379079587961,
#    'Bawang Putih': 31.590910304110874,
#    'Beras': 1.79571732111814,
#    'Cabai Merah': 17.20193443367375,
#    'Cabai Rawit': 22.545016033107682,
#    'Daging Ayam': -2.382231558066228,
#    'Daging Sapi': -0.3225127715509979,
#    'Gula Pasir': 5.155866363587425,
#    'Minyak Goreng': -2.2874342608687925,
#    'Telur Ayam': -3.9199291438866246,
#    'index': 20.37515759068064},
#   '76': {'Bawang Merah': 1.0644400975966972,
#    'Bawang Putih': 25.6540733233146,
#    'Beras': 0.008161559056851786,
#    'Cabai Merah': 33.232641270424196,
#    'Cabai Rawit': 34.06475663398456,
#    'Daging Ayam': -1.1975081338747473,
#    'Daging Sapi': -1.5362092627482782,
#    'Gula Pasir': 0.8517239295251501,
#    'Minyak Goreng': -1.1651877554233137,
#    'Telur Ayam': -7.743831056563043,
#    'index': 13.680987894236695},
#   '77': {'Bawang Merah': 21.201805994804808,
#    'Bawang Putih': 41.56060966209119,
#    'Beras': -0.8611240763369166,
#    'Cabai Merah': 44.040418186029214,
#    'Cabai Rawit': 54.66077924580899,
#    'Daging Ayam': -21.01261168189319,
#    'Daging Sapi': 3.514072337189411,
#    'Gula Pasir': -5.97506464580202,
#    'Minyak Goreng': 0.7352231758727124,
#    'Telur Ayam': -6.652449702102637,
#    'index': 2.9871209892247563},
#   '8': {'Bawang Merah': 7.270819007636352,
#    'Bawang Putih': 42.9607099704179,
#    'Beras': -2.214322743094121,
#    'Cabai Merah': 25.127411134765488,
#    'Cabai Rawit': 26.719195057892197,
#    'Daging Ayam': -5.02722981967808,
#    'Daging Sapi': 2.0526231208636947,
#    'Gula Pasir': 2.4118738404452778,
#    'Minyak Goreng': -1.8310140488714377,
#    'Telur Ayam': -5.21337439507259,
#    'index': 5.665952173962724},
#   '9': {'Bawang Merah': 15.893425570844922,
#    'Bawang Putih': 17.965498922763622,
#    'Beras': 0.024009942941072282,
#    'Cabai Merah': 19.903029244108588,
#    'Cabai Rawit': 7.2065142714239805,
#    'Daging Ayam': -2.9664660361135016,
#    'Daging Sapi': 7.029478458049887,
#    'Gula Pasir': 0.1861751152073543,
#    'Minyak Goreng': -2.1181927910444154,
#    'Telur Ayam': -0.5327961042277174,
#    'index': 15.177636367870864},
#   'KALIMANTAN UTARA': {'Bawang Merah': 19.03816645796221,
#    'Bawang Putih': 30.580273535869182,
#    'Beras': 1.7941758848888378,
#    'Cabai Merah': 45.30145853780097,
#    'Cabai Rawit': 37.028731336131735,
#    'Daging Ayam': -12.082079083713193,
#    'Daging Sapi': 22.82279839535626,
#    'Gula Pasir': 1.6364356030097669,
#    'Minyak Goreng': -1.6360177792597907,
#    'Telur Ayam': 2.4720550091255955,
#    'index': 39.688813372352364}}}

# %%
json_data.keys()
# Out:
# dict_keys(['2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1', '2018-Q2', '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4'])
